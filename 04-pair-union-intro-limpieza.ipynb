# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None) # para poder visualizar todas las columnas de los DataFrames

# %% [markdown]
# NOTA: HEchos los ejercicis de filtrado 3, 5, 7. Añadir en caso que la compañera no los haga.

# %% [markdown]
# # Pair programming Unión de Datos e Introducción a Limpieza
#     # Ejercicios Unión de Datos
# - Para realizar este pair programming deberéis usar el conjunto de datos de world-data-2023-part1.csv y el de world-data-2023-part2.csv.

# %% [markdown]
# - Tienes a tu disposición dos conjuntos de datos, "world-data-2023-part1.csv" y "world-data-2023-part2.csv", que contienen información de una serie de indicadores y datos de distintos países. Tu tarea es explorar estos conjuntos de datos y determinar qué tienen en común en términos de columnas y datos.
#
# - Luego, debes crear un nuevo DataFrame que combine la información de ambos conjuntos de datos en un solo conjunto de datos. Para hacerlo, debes seleccionar el método de unión de Pandas que consideres más apropiado para esta situación y justificar por qué crees que ese método es el mejor en tu informe.
#
# - Asegúrate de realizar los siguientes pasos:

# %% [markdown]
# 1- Explora y carga ambos conjuntos de datos en pandas DataFrames.

# %%
df_world_1 = pd.read_csv("world-data-2023_part1.csv", index_col=0)

# %%
df_world_2 = pd.read_csv("world-data-2023_part2.csv", index_col=0)

# %%
df_world_1.head(3)
# Out:
#        Country Density\n(P/Km2) Abbreviation Agricultural Land( %)  \
# 0  Afghanistan               60           AF                58.10%
# 1      Albania              105           AL                43.10%
# 2      Algeria               18           DZ                17.40%
#
#   Land Area(Km2) Armed Forces size  Birth Rate  Calling Code  \
# 0        652,230           323,000       32.49          93.0
# 1         28,748             9,000       11.78         355.0
# 2      2,381,741           317,000       24.28         213.0
#
#   Capital/Major City Co2-Emissions     CPI CPI Change (%) Currency-Code  \
# 0              Kabul         8,672   149.9          2.30%           AFN
# 1             Tirana         4,536  119.05          1.40%           ALL
# 2            Algiers       150,006  151.36          2.00%           DZD
#
#    Fertility Rate Forested Area (%) Gasoline Price
# 0            4.47             2.10%         $0.70
# 1            1.62            28.10%         $1.36
# ...

# %%
df_world_2.head(3)
# Out:
#                  GDP Gross primary education enrollment (%)  \
# 0   $19,101,353,833                                 104.00%
# 1   $15,278,077,447                                 107.00%
# 2  $169,988,236,398                                 109.90%
#
#   Gross tertiary education enrollment (%)  Infant mortality Largest city  \
# 0                                   9.70%              47.9        Kabul
# 1                                  55.00%               7.8       Tirana
# 2                                  51.40%              20.1      Algiers
#
#    Life expectancy  Maternal mortality ratio Minimum wage Official language  \
# 0             64.5                     638.0       $0.43             Pashto
# 1             78.5                      15.0       $1.12           Albanian
# 2             76.7                     112.0       $0.95             Arabic
#
#   Out of pocket health expenditure  Physicians per thousand  Population  \
# ...

# %%
df_world_2.shape
# Out:
# (195, 19)

# %%
df_world_1.shape
# Out:
# (195, 16)

# %% [markdown]
# 2- Identifica las columnas comunes entre los dos conjuntos de datos.

# %% [markdown]
# La columna común es Country

# %% [markdown]
# 3- Utiliza el método de unión de Pandas que consideres más adecuado para combinar los datos de ambos años en un solo DataFrame.

# %%
merge_world = df_world_1.merge(df_world_2, left_on = "Country", right_on= "country")
merge_world
# Out:
#          Country Density\n(P/Km2) Abbreviation Agricultural Land( %)  \
# 0    Afghanistan               60           AF                58.10%
# 1        Albania              105           AL                43.10%
# 2        Algeria               18           DZ                17.40%
# 3        Andorra              164           AD                40.00%
# 4         Angola               26           AO                47.50%
# ..           ...              ...          ...                   ...
# 190    Venezuela               32           VE                24.50%
# 191      Vietnam              314           VN                39.30%
# 192        Yemen               56           YE                44.60%
# 193       Zambia               25           ZM                32.10%
# 194     Zimbabwe               38           ZW                41.90%
#
#     Land Area(Km2) Armed Forces size  Birth Rate  Calling Code  \
# 0          652,230           323,000       32.49          93.0
# ...

# %%
# hacemos drop column porqué hay una columna repetida

merge_world = merge_world.drop(columns= ["country"])
merge_world
# Out:
#          Country Density\n(P/Km2) Abbreviation Agricultural Land( %)  \
# 0    Afghanistan               60           AF                58.10%
# 1        Albania              105           AL                43.10%
# 2        Algeria               18           DZ                17.40%
# 3        Andorra              164           AD                40.00%
# 4         Angola               26           AO                47.50%
# ..           ...              ...          ...                   ...
# 190    Venezuela               32           VE                24.50%
# 191      Vietnam              314           VN                39.30%
# 192        Yemen               56           YE                44.60%
# 193       Zambia               25           ZM                32.10%
# 194     Zimbabwe               38           ZW                41.90%
#
#     Land Area(Km2) Armed Forces size  Birth Rate  Calling Code  \
# 0          652,230           323,000       32.49          93.0
# ...

# %% [markdown]
# 4- Explica por qué elegiste ese método de unión y cómo se llevaron a cabo los pasos anteriores.
#
# Hemos hecho un merge, donde df_world1 cogía los datos de la izquierda. Hemos escogido este método porque une a través de columnas con los mismos valores . En este caso, las columnas se escribian diferte (una empieza por mayúscula y la otra no). Por eso hemos indicado el nombre de las columnas en left_on y right_on.
#
# También podríamos haber cambiado el nombre para que se llamaran igual y hacer un join.
#
# Después de unir las columnas hemos eliminado la duplicidad de columnas, que se llamaban igual.

# %% [markdown]
# ____

# %% [markdown]
#     # Ejercicios de Limpieza
# 1- Después de la unión de datos, tenemos dos columnas de "country". Elimina una de ellas.
#
# _Hecho en el paso anterior_

# %% [markdown]
# 2 - Los nombres de las columnas no son homogeneos. Cambia los nombres de las columnas de tal forma que:
# - No tengan espacios.
# - Estén en minúscula.
# - No tengan paréntesis, es decir, quitar "(%)", "(Km2)".
# - Algunas columnas tiene "\n". Eliminalos de los nombres de las columnas.
# - Algunas columnas tienen ":". Eliminalos de los nombres de las columnas.

# %%
columnas_sucias = merge_world.columns
columnas_sucias
# Out:
# Index(['Country', 'Density\n(P/Km2)', 'Abbreviation', 'Agricultural Land( %)',
#        'Land Area(Km2)', 'Armed Forces size', 'Birth Rate', 'Calling Code',
#        'Capital/Major City', 'Co2-Emissions', 'CPI', 'CPI Change (%)',
#        'Currency-Code', 'Fertility Rate', 'Forested Area (%)',
#        'Gasoline Price', 'GDP', 'Gross primary education enrollment (%)',
#        'Gross tertiary education enrollment (%)', 'Infant mortality',
#        'Largest city', 'Life expectancy', 'Maternal mortality ratio',
#        'Minimum wage', 'Official language', 'Out of pocket health expenditure',
#        'Physicians per thousand', 'Population',
#        'Population: Labor force participation (%)', 'Tax revenue (%)',
#        'Total tax rate', 'Unemployment rate', 'Urban_population',
#        'coordinates'],
#       dtype='object')

# %%
columnas_limpias =columnas_sucias.str.lower().str.replace(" ", "").str.replace("\([^)]*\)","",regex=True).str.replace("\n","").str.replace(":","")
columnas_limpias
# Out:
# Index(['country', 'density', 'abbreviation', 'agriculturalland', 'landarea',
#        'armedforcessize', 'birthrate', 'callingcode', 'capital/majorcity',
#        'co2-emissions', 'cpi', 'cpichange', 'currency-code', 'fertilityrate',
#        'forestedarea', 'gasolineprice', 'gdp',
#        'grossprimaryeducationenrollment', 'grosstertiaryeducationenrollment',
#        'infantmortality', 'largestcity', 'lifeexpectancy',
#        'maternalmortalityratio', 'minimumwage', 'officiallanguage',
#        'outofpockethealthexpenditure', 'physiciansperthousand', 'population',
#        'populationlaborforceparticipation', 'taxrevenue', 'totaltaxrate',
#        'unemploymentrate', 'urban_population', 'coordinates'],
#       dtype='object')

# %%
merge_world.columns = columnas_limpias
merge_world
# Out:
#          country density abbreviation agriculturalland   landarea  \
# 0    Afghanistan      60           AF           58.10%    652,230
# 1        Albania     105           AL           43.10%     28,748
# 2        Algeria      18           DZ           17.40%  2,381,741
# 3        Andorra     164           AD           40.00%        468
# 4         Angola      26           AO           47.50%  1,246,700
# ..           ...     ...          ...              ...        ...
# 190    Venezuela      32           VE           24.50%    912,050
# 191      Vietnam     314           VN           39.30%    331,210
# 192        Yemen      56           YE           44.60%    527,968
# 193       Zambia      25           ZM           32.10%    752,618
# 194     Zimbabwe      38           ZW           41.90%    390,757
#
#     armedforcessize  birthrate  callingcode capital/majorcity co2-emissions  \
# 0           323,000      32.49         93.0             Kabul         8,672
# ...

# %% [markdown]
# 3 - La columnas coordinates tiene la latitud y la longitud en una sola columna. Crea dos columnas nuevas, una con la longitud y otra con la latitud. Una vez hecho, elimina la columna de coordinates.

# %%
merge_world[["longitud","latitud"]] = merge_world["coordinates"].str.split(",",expand = True).get([0,1])

# También quitamos las comillas simples y paréntesis de las columnas longitud y latitud
merge_world["longitud"] = merge_world["longitud"].str.replace("'", "").str.replace("(", "")
merge_world["latitud"] = merge_world["latitud"].str.replace("'", "").str.replace(")", "")
merge_world.drop(labels ="coordinates",axis=1, inplace=True)

# %%
merge_world
# Out:
#          country density abbreviation agriculturalland   landarea  \
# 0    Afghanistan      60           AF           58.10%    652,230
# 1        Albania     105           AL           43.10%     28,748
# 2        Algeria      18           DZ           17.40%  2,381,741
# 3        Andorra     164           AD           40.00%        468
# 4         Angola      26           AO           47.50%  1,246,700
# ..           ...     ...          ...              ...        ...
# 190    Venezuela      32           VE           24.50%    912,050
# 191      Vietnam     314           VN           39.30%    331,210
# 192        Yemen      56           YE           44.60%    527,968
# 193       Zambia      25           ZM           32.10%    752,618
# 194     Zimbabwe      38           ZW           41.90%    390,757
#
#     armedforcessize  birthrate  callingcode capital/majorcity co2-emissions  \
# 0           323,000      32.49         93.0             Kabul         8,672
# ...

# %% [markdown]
# _______

# %% [markdown]
# 4 - Las columnas unemployment_rate, total_tax_rate, tax_revenue, population_labor_force_participation, out_of_pocket_health_expenditure, gross_tertiary_education_enrollment, gross_primary_education_enrollment, forested_area, cpi_change, agricultural_land tienen "%". Elimina los "%" de los valores de las columnas.

# %%
columnas_ejercicio4 = ["unemploymentrate", "totaltaxrate", "taxrevenue", "populationlaborforceparticipation", "outofpockethealthexpenditure", "grosstertiaryeducationenrollment", "grossprimaryeducationenrollment", "forestedarea", "cpichange", "agriculturalland"]

for columna in columnas_ejercicio4:
    merge_world[columna] = merge_world[columna].str.replace("%","")

merge_world
# Out:
#          country density abbreviation agriculturalland   landarea  \
# 0    Afghanistan      60           AF            58.10    652,230
# 1        Albania     105           AL            43.10     28,748
# 2        Algeria      18           DZ            17.40  2,381,741
# 3        Andorra     164           AD            40.00        468
# 4         Angola      26           AO            47.50  1,246,700
# ..           ...     ...          ...              ...        ...
# 190    Venezuela      32           VE            24.50    912,050
# 191      Vietnam     314           VN            39.30    331,210
# 192        Yemen      56           YE            44.60    527,968
# 193       Zambia      25           ZM            32.10    752,618
# 194     Zimbabwe      38           ZW            41.90    390,757
#
#     armedforcessize  birthrate  callingcode capital/majorcity co2-emissions  \
# 0           323,000      32.49         93.0             Kabul         8,672
# ...

# %% [markdown]
# 5 - Haz lo mismo para las columnas de gasoline_price, gdp, minimum_wage, pero eliminando "$".

# %%
columnas_ejercicio5 = ["gasolineprice", "gdp", "minimumwage"]

for columna in columnas_ejercicio5:
    merge_world[columna] = merge_world[columna].str.replace("$","")

merge_world
# Out:
#          country density abbreviation agriculturalland   landarea  \
# 0    Afghanistan      60           AF            58.10    652,230
# 1        Albania     105           AL            43.10     28,748
# 2        Algeria      18           DZ            17.40  2,381,741
# 3        Andorra     164           AD            40.00        468
# 4         Angola      26           AO            47.50  1,246,700
# ..           ...     ...          ...              ...        ...
# 190    Venezuela      32           VE            24.50    912,050
# 191      Vietnam     314           VN            39.30    331,210
# 192        Yemen      56           YE            44.60    527,968
# 193       Zambia      25           ZM            32.10    752,618
# 194     Zimbabwe      38           ZW            41.90    390,757
#
#     armedforcessize  birthrate  callingcode capital/majorcity co2-emissions  \
# 0           323,000      32.49         93.0             Kabul         8,672
# ...

# %%
merge_world.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 35 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   country                            195 non-null    object
#  1   density                            195 non-null    object
#  2   abbreviation                       188 non-null    object
#  3   agriculturalland                   188 non-null    object
#  4   landarea                           194 non-null    object
#  5   armedforcessize                    171 non-null    object
#  6   birthrate                          189 non-null    float64
#  7   callingcode                        194 non-null    float64
#  8   capital/majorcity                  192 non-null    object
#  9   co2-emissions                      188 non-null    object
#  10  cpi                                178 non-null    object
# ...

# %% [markdown]
# 6 - Guarda el DataFrame para usarlo en el pairprogramming de mañana.

# %%
merge_world.to_csv("merge_world.csv",index = False)

# %% [markdown]
# ___

# %% [markdown]
#     # Ejercicios de Filtrado
# 1 - Encuentra todos los países cuya mortalidad infantil esté entre 40 y 50 personas por kilómetro cuadrado.

# %%
# convertimos la columna a float
merge_world["density"] = merge_world["density"].str.replace(",",".").astype(str).astype(float)

# %%
condicion_1 = merge_world.loc[(merge_world["density"]>= 40)&(merge_world["density"]<= 50)]
print (condicion_1)
# Out:
#                               country  density abbreviation agriculturalland  \
# 15                            Belarus     47.0           BY            42.00
# 37                           Colombia     46.0           CO            40.30
# 45   Democratic Republic of the Congo     40.0           CD            11.60
# 47                           Djibouti     43.0           DJ            73.40
# 53                  Equatorial Guinea     50.0           GQ            10.10
# 58                               Fiji     49.0           FJ            23.30
# 99                          Lithuania     43.0           LT            47.20
# 101                        Madagascar     48.0           MG            71.20
# 115                        Montenegro     47.0           ME            19.00
# 117                        Mozambique     40.0           MZ            63.50
# 161                      South Africa     49.0           ZA            79.80
#
# ...

# %%
condicion_1_mortalidad_infan = condicion_1[["country","infantmortality"]]
condicion_1_mortalidad_infan

# Entendemos que se piden la mortalidad infantil de los paises que tienen una densidad entre 40 y 50 km2
# Out:
#                               country  infantmortality
# 15                            Belarus              2.6
# 37                           Colombia             12.2
# 45   Democratic Republic of the Congo             68.2
# 47                           Djibouti             49.8
# 53                  Equatorial Guinea             62.6
# 58                               Fiji             21.6
# 99                          Lithuania              3.3
# 101                        Madagascar             38.2
# 115                        Montenegro              2.3
# 117                        Mozambique             54.0
# 161                      South Africa             28.5

# %% [markdown]
# 2- Encuentra los países cuyas tasas de natalidad son mayores o iguales a 20 y su esperanza de vida es mayor de 75 años.

# %%
merge_world.columns
#vemos que las columnas que nos interesan son: "birthrate" y "lifeexpectancy" y "country"
# Out:
# Index(['country', 'density', 'abbreviation', 'agriculturalland', 'landarea',
#        'armedforcessize', 'birthrate', 'callingcode', 'capital/majorcity',
#        'co2-emissions', 'cpi', 'cpichange', 'currency-code', 'fertilityrate',
#        'forestedarea', 'gasolineprice', 'gdp',
#        'grossprimaryeducationenrollment', 'grosstertiaryeducationenrollment',
#        'infantmortality', 'largestcity', 'lifeexpectancy',
#        'maternalmortalityratio', 'minimumwage', 'officiallanguage',
#        'outofpockethealthexpenditure', 'physiciansperthousand', 'population',
#        'populationlaborforceparticipation', 'taxrevenue', 'totaltaxrate',
#        'unemploymentrate', 'urban_population', 'longitud', 'latitud'],
#       dtype='object')

# %%
# merge_world.loc[(merge_world["density"]>= 40)&(merge_world["density"]<= 50)]

#1 - Establecemos la condición:

condicion_2 = (merge_world["birthrate"] >= 20) & (merge_world["lifeexpectancy"] >= 75)
# 2- Aplicamos al condición, filtrando  por país

df_condicion_2 = merge_world.loc[condicion_2, ("country")]

# pasamos la serie a DF para que sea más legible:
df_condicion_2 = pd.DataFrame(df_condicion_2)
df_condicion_2
# Out:
#      country
# 2    Algeria
# 74  Honduras
# 82    Israel

# %% [markdown]
# 3 - Encuentra las ciudades cuyos paises contienen la palabra "la" en su nombre.

# %%
# 'capital/majorcity'

# 'country' 

# condición "la"

condicion_3 = "la"

paises_con_la = (merge_world['country'].str.lower().str.contains(condicion_3))
paises_con_la
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 190     True
# 191    False
# 192    False
# 193    False
# 194    False
# Name: country, Length: 195, dtype: bool

# %%
# Supongamos que tu DataFrame tiene una columna llamada "city" y otra llamada "country"
palabra_a_buscar = "la"
paises_con_la = merge_world['country'].str.lower().str.contains(palabra_a_buscar.lower())

# %%
# Filtrar el DataFrame utilizando la condición
ciudades = merge_world.loc[paises_con_la ,['capital/majorcity', 'country']]
ciudades
# Out:
#     capital/majorcity              country
# 4              Luanda               Angola
# 13              Dhaka           Bangladesh
# 15              Minsk              Belarus
# 59           Helsinki              Finland
# 68     Guatemala City            Guatemala
# 76          Reykjav��              Iceland
# 81             Dublin  Republic of Ireland
# 92          Vientiane                 Laos
# 93               Riga               Latvia
# 102          Lilongwe               Malawi
# 103      Kuala Lumpur             Malaysia
# 107            Majuro     Marshall Islands
# 122         Amsterdam          Netherlands
# 123        Wellington          New Zealand
# 132         Ngerulmud                Palau
# 139            Warsaw               Poland
# 159           Honiara      Solomon Islands
# 165           Colombo            Sri Lanka
# 169              Bern          Switzerland
# 173           Bangkok             Thailand
# 190           Caracas            Venezuela

# %% [markdown]
# 4 - Encuentra los países cuyos medicos por cada 1000 habitantes (physicians_per_thousand) sea mayores de 5.

# %%
# physiciansperthousand

# 1 - definimos la condición
condicion_4 = (merge_world["physiciansperthousand"])>5
# 2 - aplicamos la condición, filtrando por paises
df_condicion_4 = merge_world.loc[condicion_4, ("country")]

# el resultado es una Serie. La convertimos a DF para que sea más legible:

df_condicion_4 = pd.DataFrame(df_condicion_4)
df_condicion_4
# Out:
#         country
# 9       Austria
# 15      Belarus
# 42         Cuba
# 63      Georgia
# 66       Greece
# 99    Lithuania
# 113      Monaco
# 140    Portugal
# 149  San Marino
# 187     Uruguay

# %% [markdown]
# 5 - Encuentra los países cuya tasa de fertilidad sea mayor a 6.

# %%
# 'fertilityrate'

condicion_5 = (merge_world['fertilityrate']>6)

df_condicion_5 = merge_world.loc[condicion_5, ("country", "fertilityrate")]
df_condicion_5
# Out:
#      country  fertilityrate
# 125    Niger           6.91
# 160  Somalia           6.07

# %% [markdown]
# 6 - Encuentra los países cuya moneda es el euro (EUR) y tienen una tasa de natalidad superior al promedio.

# %%
#currency-code
# birthrate -> hacer promedio y coger las que son superior

# %%
merge_world.head()
# Out:
#        country  density abbreviation agriculturalland   landarea  \
# 0  Afghanistan     60.0           AF            58.10    652,230
# 1      Albania    105.0           AL            43.10     28,748
# 2      Algeria     18.0           DZ            17.40  2,381,741
# 3      Andorra    164.0           AD            40.00        468
# 4       Angola     26.0           AO            47.50  1,246,700
#
#   armedforcessize  birthrate  callingcode capital/majorcity co2-emissions  \
# 0         323,000      32.49         93.0             Kabul         8,672
# 1           9,000      11.78        355.0            Tirana         4,536
# 2         317,000      24.28        213.0           Algiers       150,006
# 3             NaN       7.20        376.0  Andorra la Vella           469
# 4         117,000      40.73        244.0            Luanda        34,693
#
#       cpi cpichange currency-code  fertilityrate forestedarea gasolineprice  \
# ...

# %%
condicion_6 = (merge_world["birthrate"] > merge_world["birthrate"].mean()) & (merge_world["currency-code"] == "EUR")
df_condicion_6 = merge_world.loc[condicion_6, "country"]
df_condicion_6 = pd.DataFrame(df_condicion_6)
df_condicion_6 

#nota: no salen datos, por lo que no hay paises que cumplan esta condición.
# Out:
# Empty DataFrame
# Columns: [country]
# Index: []

# %% [markdown]
# 7 - Encuentra los países cuyas tasas de mortalidad infantil son superiores a 70.

# %%
condicion_7 = (merge_world['infantmortality'] >70)
df_condicion_7 = merge_world.loc[condicion_7, ["country", 'infantmortality']]
df_condicion_7 = pd.DataFrame(df_condicion_7)
df_condicion_7
# Out:
#                       country  infantmortality
# 33   Central African Republic             84.5
# 34                       Chad             71.4
# 126                   Nigeria             75.7
# 155              Sierra Leone             78.5
# 160                   Somalia             76.6
